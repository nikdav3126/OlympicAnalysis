# %%
import pandas as pd

# %%
gdp_df = pd.read_csv('./archive/GDP.csv')
data_df = pd.read_csv('./archive/Data.csv')

# %%
# attach the GDP percent of global
glob_gdp_perc = []
gdp_df = gdp_df[gdp_df['Country Code'] == 'WLD']
for index, row in data_df.iterrows():
    NOC = row['NOC']
    year = str(row['Year'])
    ngdp = row['GDP']
    ref_df = gdp_df[gdp_df['Country Code'] == NOC]
    ggdp = gdp_df[year].iat[0]
    glob_gdp_perc.append(ngdp/ggdp)
data_df['Global_GDP%'] = glob_gdp_perc

# %%
data_df.head()
# Out:
#    Unnamed: 0  ID                      Name Sex   Age  Height  Weight  \
# 0           0   1                 A Dijiang   M  24.0   180.0    80.0
# 1           1   2                  A Lamusi   M  23.0   170.0    60.0
# 2           2   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 3           3   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 4           4   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
#
#           Team  NOC        Games  ...                               Event  \
# 0        China  CHN  1992 Summer  ...         Basketball Men's Basketball
# 1        China  CHN  2012 Summer  ...        Judo Men's Extra-Lightweight
# 2  Netherlands  NLD  1988 Winter  ...    Speed Skating Women's 500 metres
# 3  Netherlands  NLD  1988 Winter  ...  Speed Skating Women's 1,000 metres
# 4  Netherlands  NLD  1992 Winter  ...    Speed Skating Women's 500 metres
#
#   Medal Host       Nat_Pop Global_Pop% Rural_Pop%  Life_Expect           GDP  \
# ...

# %%
data_df.to_csv('./archive/Data.csv')
